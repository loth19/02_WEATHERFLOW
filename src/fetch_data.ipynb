# %%
# Charge les variables d'environnement depuis le fichier .env
from dotenv import load_dotenv
import os

# %%
# Chemin explicite du .env pour eviter les erreurs de dossier courant
from pathlib import Path

load_dotenv(dotenv_path="C:/Users/CODO/02_WeatherFlow/.env", override=True)
api_key = os.getenv("OPENWEATHER_API_KEY")

# Verification rapide: True + longueur > 0 signifie que la cle est bien chargee
print("key loaded:", api_key is not None, "length:", len(api_key) if api_key else 0)
# Out:
# key loaded: True length: 32

# %%
# Bibliotheque HTTP pour appeler l'API OpenWeather
import requests
import json

# %%
# Endpoint meteo current weather
url = "https://api.openweathermap.org/data/2.5/weather"

# Liste des villes a interroger
villes = ["paris", "Londres", "Madrid", "Rome", "Berlin"]


for ville in villes:
    # Parametres de la requete pour une seule ville
    param = {
        "q": ville,
        "appid": api_key,
        "units": "metric",
        "lang": "fr"
    }

    # Appel API + conversion JSON
    response = requests.get(url, params=param)
    data = response.json()

 # Sauvegarde brute: 1 JSON par ville
    with open(raw_dir / f"{ville.lower()}.json", "w", encoding="utf-8") as f:
        json.dump(data, f, ensure_ascii=False, indent=2)

# %%
data
# Out:
# {'coord': {'lon': 13.4105, 'lat': 52.5244},
#  'weather': [{'id': 800,
#    'main': 'Clear',
#    'description': 'ciel dégagé',
#    'icon': '01d'}],
#  'base': 'stations',
#  'main': {'temp': 9.53,
#   'feels_like': 9.07,
#   'temp_min': 7.31,
#   'temp_max': 10.6,
#   'pressure': 1017,
#   'humidity': 44,
#   'sea_level': 1017,
#   'grnd_level': 1012},
#  'visibility': 10000,
#  'wind': {'speed': 1.54, 'deg': 180},
#  'clouds': {'all': 0},
#  'dt': 1775824686,
#  'sys': {'type': 2,
#   'id': 2011538,
#   'country': 'DE',
#   'sunrise': 1775794809,
#   'sunset': 1775843692},
#  'timezone': 7200,
#  'id': 2950159,
#  'name': 'Berlin',
#  'cod': 200}

# %%
resultats
# Out:
# [{'ville': 'Paris',
#   'temperature': 15.39,
#   'ressenti': 14.06,
#   'humidite': 41,
#   'vitesse_vent': 2.57,
#   'description_meteo': 'ciel dégagé',
#   'status': 200},
#  {'ville': 'Londres',
#   'temperature': 12.69,
#   'ressenti': 11.19,
#   'humidite': 45,
#   'vitesse_vent': 3.6,
#   'description_meteo': 'couvert',
#   'status': 200},
#  {'ville': 'Madrid',
#   'temperature': 25.91,
#   'ressenti': 25.21,
#   'humidite': 25,
#   'vitesse_vent': 3.6,
#   'description_meteo': 'ciel dégagé',
#   'status': 200},
#  {'ville': 'Rome',
#   'temperature': 4.98,
#   'ressenti': 3.87,
#   'humidite': 87,
#   'vitesse_vent': 1.54,
#   'description_meteo': 'ciel dégagé',
#   'status': 200},
#  {'ville': 'Berlin',
#   'temperature': 9.53,
#   'ressenti': 9.07,
#   'humidite': 44,
#   'vitesse_vent': 1.54,
#   'description_meteo': 'ciel dégagé',
#   'status': 200}]
